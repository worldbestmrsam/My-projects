# %% [markdown]
# <a href="https://colab.research.google.com/github/worldbestmrsam/My-projects/blob/main/Another_copy_of_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing pandas as pd
import pandas as pd
import numpy as np

# %%
#Reading the datasets into pandas Dataframe
myData = pd.read_excel('/content/supermarket_sales.xlsx')

# %%
#Displaying the last sections of the datasets
myData.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date      Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46:00  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16:00  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22:00     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33:00     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28:00     Cash
#
# ...

# %%
#Checked the total number of columns and rows present in the the datasets
myData.shape
# Out:
# (1000, 17)

# %%
#This describes the details of the overall statistics of the datasets
myData.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
#Cleaning the data by Checking for inconsistencies in each column of the datasets
#The datasets was found to be clean with no missing values.
myData.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#Checking the attributes tittle of each of the columns
myData.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
# Using the Groupby and sort function to know the total revenue generated by each of the branches
myData.groupby('Branch')['Total'].sum().sort_values()
# Out:
# Branch
# B    106197.6720
# A    106200.3705
# C    110568.7065
# Name: Total, dtype: float64

# %%
##Group Product by the Sales [sum](Total) to know which products generate highest revenue
#Food and beverages generated the highest revenue
myData.groupby('Product line')['Total'].sum().sort_values()
# Out:
# Product line
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Fashion accessories       54305.8950
# Electronic accessories    54337.5315
# Sports and travel         55122.8265
# Food and beverages        56144.8440
# Name: Total, dtype: float64

# %%
#Checked the unique attributes in the column tittled 'Branch'
myData.Branch.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
#This will list out the branches in their numbers
myData['Branch'].tolist()

# %%
#Checked the total revenue generated from each Product line across the various Branches.
myData.groupby('Product line')['Total'].sum().sort_values()
# Out:
# Product line
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Fashion accessories       54305.8950
# Electronic accessories    54337.5315
# Sports and travel         55122.8265
# Food and beverages        56144.8440
# Name: Total, dtype: float64

# %%
#Filtered the dataset into branches and keep them in a separate dataframe and for each branch:
# check the performance of the products
#Represented the dataframe for branch A with dfA_modified, using the loc function.

dfA_modified=myData.loc[myData["Branch"]=="A"]

# %%
#The content of the dataframe dfA_modified has more information than required

dfA_modified
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
#the dataframe dfA_modified(above) was then stremlined to the required query and put in a new dataframe df_A
df_A = dfA_modified[['Branch', 'Product line', 'Customer type', 'Total']]

# %%
#performance of the products for Branch A
df_A
# Out:
#     Branch            Product line Customer type     Total
# 0        A       Health and beauty        Member  548.9715
# 2        A      Home and lifestyle        Normal  340.5255
# 3        A       Health and beauty        Member  489.0480
# 4        A       Sports and travel        Normal  634.3785
# 6        A  Electronic accessories        Member  433.6920
# ..     ...                     ...           ...       ...
# 990      A      Food and beverages        Normal  296.9400
# 992      A  Electronic accessories        Normal  121.8630
# 997      A      Food and beverages        Member   33.4320
# 998      A      Home and lifestyle        Normal   69.1110
# 999      A     Fashion accessories        Member  649.2990
#
# [340 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %%
##This command helped visualized the performances of each product line in Branch
#Home and Lifestyle generated the most revenue for BranchA
df_A.groupby('Product line')['Total'].sum().sort_values()
# Out:
# Product line
# Health and beauty         12597.7530
# Fashion accessories       16332.5085
# Food and beverages        17163.1005
# Electronic accessories    18317.1135
# Sports and travel         19372.6995
# Home and lifestyle        22417.1955
# Name: Total, dtype: float64

# %%
#This will only pull out the Branch B, though with other columns not required
dfB_modified=myData.loc[myData["Branch"]=="B"]

# %%
#As applicable to A

df_B= dfB_modified[['Branch', 'Product line', 'Total']]

# %%
df_B
# Out:
#     Branch            Product line     Total
# 9        B      Food and beverages   172.746
# 10       B     Fashion accessories    60.816
# 11       B  Electronic accessories   107.142
# 15       B       Sports and travel   590.436
# 19       B      Home and lifestyle    84.630
# ..     ...                     ...       ...
# 987      B       Health and beauty   520.800
# 989      B       Health and beauty   633.108
# 991      B       Sports and travel   804.300
# 993      B     Fashion accessories   183.645
# 996      B      Home and lifestyle  1022.490
#
# [332 rows x 3 columns]

# %%
df_B.groupby('Product line')['Total'].sum().sort_values()
#This is the performances of the product line in BranchB
#Sports and Travel generated the most revenue for BranchB
# Out:
# Product line
# Food and beverages        15214.8885
# Fashion accessories       16413.3165
# Electronic accessories    17051.4435
# Home and lifestyle        17549.1645
# Health and beauty         19980.6600
# Sports and travel         19988.1990
# Name: Total, dtype: float64

# %%
dfC_modified=myData.loc[myData["Branch"]=="C"]

# %%
df_C= dfC_modified[['Branch', 'Product line', 'Total']]

# %%
##This is the performances of the product line in BranchC
df_C
# Out:
#     Branch            Product line     Total
# 1        C  Electronic accessories   80.2200
# 5        C  Electronic accessories  627.6165
# 7        C      Home and lifestyle  772.3800
# 20       C  Electronic accessories  451.7100
# 34       C      Food and beverages  417.5640
# ..     ...                     ...       ...
# 983      C       Health and beauty  734.7060
# 984      C  Electronic accessories  708.3195
# 988      C  Electronic accessories  864.5700
# 994      C  Electronic accessories   63.9975
# 995      C       Health and beauty   42.3675
#
# [328 rows x 3 columns]

# %%
#This is the performances of the product line in Branch
#Food and beverages generated the most revenue for BranchC

df_C.groupby('Product line')['Total'].sum().sort_values()
# Out:
# Product line
# Home and lifestyle        13895.5530
# Sports and travel         15761.9280
# Health and beauty         16615.3260
# Electronic accessories    18968.9745
# Fashion accessories       21560.0700
# Food and beverages        23766.8550
# Name: Total, dtype: float64

# %%
df_A
# Out:
#     Branch            Product line Customer type     Total
# 0        A       Health and beauty        Member  548.9715
# 2        A      Home and lifestyle        Normal  340.5255
# 3        A       Health and beauty        Member  489.0480
# 4        A       Sports and travel        Normal  634.3785
# 6        A  Electronic accessories        Member  433.6920
# ..     ...                     ...           ...       ...
# 990      A      Food and beverages        Normal  296.9400
# 992      A  Electronic accessories        Normal  121.8630
# 997      A      Food and beverages        Member   33.4320
# 998      A      Home and lifestyle        Normal   69.1110
# 999      A     Fashion accessories        Member  649.2990
#
# [340 rows x 4 columns]

# %%
#performance based on customer type in BranchA
df_A.groupby('Customer type')['Total'].sum().sort_values()
# Out:
# Customer type
# Normal    52562.8950
# Member    53637.4755
# Name: Total, dtype: float64

# %%
df_B= dfB_modified[['Branch', 'Product line','Customer type', 'Total']]

# %%
#performance based on customer type in BranchB

df_B.groupby('Customer type')['Total'].sum().sort_values()
# Out:
# Customer type
# Normal    52492.986
# Member    53704.686
# Name: Total, dtype: float64

# %%
#performance based on customer type in BranchC

df_C= dfC_modified[['Branch', 'Product line','Customer type', 'Total']]

# %%
#performance based on customer type in BranchC

df_C.groupby('Customer type')['Total'].sum().sort_values()
# Out:
# Customer type
# Normal    53687.4240
# Member    56881.2825
# Name: Total, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
performances_data=myData.groupby('Product line')['Total'].sum().sort_values()
performances_data
# Out:
# Product line
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Fashion accessories       54305.8950
# Electronic accessories    54337.5315
# Sports and travel         55122.8265
# Food and beverages        56144.8440
# Name: Total, dtype: float64

# %%
#BranchC geberated the highest Revenue
Best_branch=myData.groupby('Branch')['Total'].sum().sort_values()
Best_branch
# Out:
# Branch
# B    106197.6720
# A    106200.3705
# C    110568.7065
# Name: Total, dtype: float64

# %%
#Using the appropriate Visual Representation for the analysis
# Plotting the bar chart

performances_data.plot(kind='bar')

# Adding labels and title
plt.xlabel('Product line')
plt.ylabel('Total')
plt.title('Overall Product Line Performances')
# Out:
# Text(0.5, 1.0, 'Overall Product Line Performances')

# %%
#Evident from the visual representation of the analysis of this datasets, BrannchC recorded the overall best sales

Best_branch.plot(kind='bar')
plt.ylabel('Total')
plt.xlabel('Branch')
plt.title('Distribution of Profits Per Branch')
# Out:
# Text(0.5, 1.0, 'Distribution of Profits Per Branch')
